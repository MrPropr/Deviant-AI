# %% [markdown]
# # Deviant-AI Pilot Notebook
#
# This notebook is a safe placeholder for Kaggle or Colab pilot work. Use sanitized examples or aggregate outputs only.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('../data/sanitized_examples.jsonl')
examples = pd.read_json(data_path, lines=True)
examples

# %% [markdown]
# Next steps: run the sanitized pipeline locally, then load aggregate CSV files from `tables/` for analysis and plotting.
